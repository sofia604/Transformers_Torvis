# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler 

np.random.seed(0)

# %%
filename = '../Data/SCADA_data_WT2337.csv'
datos=pd.read_csv(filename)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.DataFrame({'date_time': datos['date_time'] ,'TempEjeLento_1': datos['TempEjeLento_1'], 'TempAmbMean': datos['TempAmbMean'], 'TempRodamMultipMean': datos['TempRodamMultipMean'], 'TempCojLAMean': datos['TempCojLAMean'],'TempCojLOAMean': datos['TempCojLOAMean'], 'TempGenMean': datos['TempGenMean'], 'PotMean': datos['PotMean'], 'VelRotorMean': datos['VelRotorMean']})

# %%
cols = df.columns.tolist()
cols
# Out:
# ['date_time',
#  'TempEjeLento_1',
#  'TempAmbMean',
#  'TempRodamMultipMean',
#  'TempCojLAMean',
#  'TempCojLOAMean',
#  'TempGenMean',
#  'PotMean',
#  'VelRotorMean']

# %% [markdown]
# ## Pre-procesamiento

# %%
#PotMean
df['PotMean'][df['PotMean']< 0] = None
df['PotMean'][df['PotMean']> 2000] = None
#TempAmbMean
df['TempAmbMean'][df['TempAmbMean']< -5] = None
df['TempAmbMean'][df['TempAmbMean']> 40] = None
#TempCojLAMean
df['TempCojLAMean'][df['TempCojLAMean']< 0] = None
df['TempCojLAMean'][df['TempCojLAMean']> 120] = None
#TempCojLOAMean
df['TempCojLOAMean'][df['TempCojLOAMean']< 0] = None
df['TempCojLOAMean'][df['TempCojLOAMean']> 120] = None
#TempEjeLento_1
df['TempEjeLento_1'][df['TempEjeLento_1']< 0] = None
df['TempEjeLento_1'][df['TempEjeLento_1']> 120] = None
#TempGenMean
df['TempGenMean'][df['TempGenMean']< 0] = None
df['TempGenMean'][df['TempGenMean']> 175] = None
#TempRodamMultipMean
df['TempRodamMultipMean'][df['TempRodamMultipMean']< 0] = None
df['TempRodamMultipMean'][df['TempRodamMultipMean']> 120] = None
#VelRotorMean
df['VelRotorMean'][df['VelRotorMean']< 0] = None
df['VelRotorMean'][df['VelRotorMean']> 50] = None

# %%
df['TempAmbMean']=df['TempAmbMean'].interpolate(method='pchip', order=3, limit_area='inside')
df['TempAmbMean']=df['TempAmbMean'].fillna(method='backfill')
df['TempAmbMean']=df['TempAmbMean'].fillna(method='ffill')

df['TempEjeLento_1']=df['TempEjeLento_1'].interpolate(method='pchip', order=3)
df['TempEjeLento_1']=df['TempEjeLento_1'].fillna(method='backfill')

df['TempRodamMultipMean']=df['TempRodamMultipMean'].interpolate(method='pchip', order=3)
df['TempRodamMultipMean']=df['TempRodamMultipMean'].fillna(method='backfill')

df['TempCojLAMean']=df['TempCojLAMean'].interpolate(method='pchip', order=3)
df['TempCojLAMean']=df['TempCojLAMean'].fillna(method='backfill')

df['TempCojLOAMean']=df['TempCojLOAMean'].interpolate(method='pchip', order=3)
df['TempCojLOAMean']=df['TempCojLOAMean'].fillna(method='backfill')

df['TempGenMean']=df['TempGenMean'].interpolate(method='pchip', order=3)
df['TempGenMean']=df['TempGenMean'].fillna(method='backfill')

df['PotMean']=df['PotMean'].interpolate(method='pchip', order=3)
df['PotMean']=df['PotMean'].fillna(method='backfill')

df['VelRotorMean']=df['VelRotorMean'].interpolate(method='pchip', order=3)
df['VelRotorMean']=df['VelRotorMean'].fillna(method='backfill')

df['TempEjeLento_1']=df['TempEjeLento_1'].fillna(method='ffill')
df['TempRodamMultipMean']=df['TempRodamMultipMean'].fillna(method='ffill')
df['TempCojLAMean']=df['TempCojLAMean'].fillna(method='ffill')
df['TempCojLOAMean']=df['TempCojLOAMean'].fillna(method='ffill')
df['TempGenMean']=df['TempGenMean'].fillna(method='ffill')
df['PotMean']=df['PotMean'].fillna(method='ffill')
df['VelRotorMean']=df['VelRotorMean'].fillna(method='ffill')

# %%
df.reset_index(drop=True, inplace=True)

# %%
datos_listos=df.copy()

# %%
datos_t=pd.DataFrame({ 'TempEjeLento_1':df['TempEjeLento_1'],'date_time': df['date_time'] ,})
datos_t.drop([0], inplace=True)
datos_t.reset_index(drop=True, inplace=True)
datos_t
# Out:
#         TempEjeLento_1              date_time
# 0         1.999570e+01  2013-01-01 00:10:00.0
# 1         1.999570e+01  2013-01-01 00:20:00.0
# 2         1.999570e+01  2013-01-01 00:30:00.0
# 3         1.999570e+01  2013-01-01 00:40:00.0
# 4         1.999570e+01  2013-01-01 00:50:00.0
# ...                ...                    ...
# 358128    8.684532e+08  2019-10-28 00:10:00.0
# 358129    8.685083e+08  2019-10-28 00:20:00.0
# 358130    8.685633e+08  2019-10-28 00:30:00.0
# 358131    8.686183e+08  2019-10-28 00:40:00.0
# 358132    8.686734e+08  2019-10-28 00:50:00.0
#
# [358133 rows x 2 columns]

# %%
datos_tmenos1=pd.DataFrame({'TempEjeLento_1-1': df['TempEjeLento_1'],'TempAmbMean-1': df['TempAmbMean'], 'TempRodamMultipMean-1': df['TempRodamMultipMean'],'TempCojLOAMean-1': df['TempCojLOAMean'], 'TempGenMean-1': df['TempGenMean'], 'PotMean-1': df['PotMean'], 'VelRotorMean-1': df['VelRotorMean']})
datos_tmenos1.drop([len(df['VelRotorMean'])-1], inplace=True)
datos_tmenos1.reset_index(drop=True, inplace=True)
datos_tmenos1
# Out:
#         TempEjeLento_1-1  TempAmbMean-1  TempRodamMultipMean-1  \
# 0           1.999570e+01        2.39048                64.1288
# 1           1.999570e+01        2.39048                64.1288
# 2           1.999570e+01        2.39048                64.1288
# 3           1.999570e+01        2.39048                64.1288
# 4           1.999570e+01        2.39048                64.1288
# ...                  ...            ...                    ...
# 358128      8.683982e+08       18.02380                57.0572
# 358129      8.684532e+08       17.96310                58.0939
# 358130      8.685083e+08       17.90240                59.1305
# 358131      8.685633e+08       17.84170                60.1671
# 358132      8.686183e+08       17.78090                61.2038
#
#         TempCojLOAMean-1  TempGenMean-1  PotMean-1  VelRotorMean-1
# 0                18.8788        38.4616    229.510         12.1639
# 1                18.8788        38.4616    229.510         12.1639
# 2                18.8788        38.4616    229.510         12.1639
# 3                18.8788        38.4616    229.510         12.1639
# 4                18.8788        38.4616    229.510         12.1639
# ...                  ...            ...        ...             ...
# 358128           36.1502        50.8232    153.996         11.7559
# 358129           36.2752        51.2622    190.546         12.1454
# 358130           36.4003        51.7013    190.080         12.1656
# 358131           36.5253        52.1404    164.409         11.9320
# 358132           36.6503        52.5794    171.453         11.9673
#
# [358133 rows x 7 columns]

# %%
datos_listos=pd.DataFrame({'date_time': datos_t['date_time'], 'TempEjeLento_1-1': datos_tmenos1['TempEjeLento_1-1'],'TempAmbMean-1': datos_tmenos1['TempAmbMean-1'],'TempRodamMultipMean-1': datos_tmenos1['TempRodamMultipMean-1'],'TempCojLOAMean-1': datos_tmenos1['TempCojLOAMean-1'],'TempGenMean-1': datos_tmenos1['TempGenMean-1'], 'PotMean-1': datos_tmenos1['PotMean-1'], 'VelRotorMean-1': datos_tmenos1['VelRotorMean-1'],'TempEjeLento_1': datos_t['TempEjeLento_1']})
datos_listos
# Out:
#                     date_time  TempEjeLento_1-1  TempAmbMean-1  \
# 0       2013-01-01 00:10:00.0      1.999570e+01        2.39048
# 1       2013-01-01 00:20:00.0      1.999570e+01        2.39048
# 2       2013-01-01 00:30:00.0      1.999570e+01        2.39048
# 3       2013-01-01 00:40:00.0      1.999570e+01        2.39048
# 4       2013-01-01 00:50:00.0      1.999570e+01        2.39048
# ...                       ...               ...            ...
# 358128  2019-10-28 00:10:00.0      8.683982e+08       18.02380
# 358129  2019-10-28 00:20:00.0      8.684532e+08       17.96310
# 358130  2019-10-28 00:30:00.0      8.685083e+08       17.90240
# 358131  2019-10-28 00:40:00.0      8.685633e+08       17.84170
# 358132  2019-10-28 00:50:00.0      8.686183e+08       17.78090
#
#         TempRodamMultipMean-1  TempCojLOAMean-1  TempGenMean-1  PotMean-1  \
# 0                     64.1288           18.8788        38.4616    229.510
# 1                     64.1288           18.8788        38.4616    229.510
# 2                     64.1288           18.8788        38.4616    229.510
# 3                     64.1288           18.8788        38.4616    229.510
# 4                     64.1288           18.8788        38.4616    229.510
# ...                       ...               ...            ...        ...
# 358128                57.0572           36.1502        50.8232    153.996
# 358129                58.0939           36.2752        51.2622    190.546
# 358130                59.1305           36.4003        51.7013    190.080
# 358131                60.1671           36.5253        52.1404    164.409
# 358132                61.2038           36.6503        52.5794    171.453
#
#         VelRotorMean-1  TempEjeLento_1
# 0              12.1639    1.999570e+01
# 1              12.1639    1.999570e+01
# 2              12.1639    1.999570e+01
# 3              12.1639    1.999570e+01
# 4              12.1639    1.999570e+01
# ...                ...             ...
# 358128         11.7559    8.684532e+08
# 358129         12.1454    8.685083e+08
# 358130         12.1656    8.685633e+08
# 358131         11.9320    8.686183e+08
# 358132         11.9673    8.686734e+08
#
# [358133 rows x 9 columns]

# %%
from datetime import datetime,timedelta
datos_listos['date_time']=pd.to_datetime(datos_listos['date_time'])

# %%
data_tv=datos_listos.copy()
mask = ((data_tv['date_time'] >= '2017-02-06 00:00:00') & (data_tv['date_time'] < '2018-01-01 00:00:00') ) 
train_tv=data_tv.loc[mask]
train_tv.reset_index(drop=True, inplace=True)

# %%
longitud=len(train_tv)
#longitud=longitud*70/100
longitud=(longitud)/144
longitud=longitud*90/100
longitud=round(longitud)
longitud=longitud*144
longitud
# Out:
# 42624

# %%
training=train_tv.loc[0:round(longitud)-1]
training.reset_index(drop=True, inplace=True)
training
# Out:
#                 date_time  TempEjeLento_1-1  TempAmbMean-1  \
# 0     2017-02-06 00:00:00         22.879502        7.43394
# 1     2017-02-06 00:10:00         22.880098        7.39546
# 2     2017-02-06 00:20:00         22.880692        7.35698
# 3     2017-02-06 00:30:00         22.881285        7.31849
# 4     2017-02-06 00:40:00         22.881875        7.28001
# ...                   ...               ...            ...
# 42619 2017-11-28 23:10:00         22.229200       10.87230
# 42620 2017-11-28 23:20:00         22.365700       10.87490
# 42621 2017-11-28 23:30:00         22.493200       10.87750
# 42622 2017-11-28 23:40:00         22.582200       10.88000
# 42623 2017-11-28 23:50:00         22.666800       10.88260
#
#        TempRodamMultipMean-1  TempCojLOAMean-1  TempGenMean-1  PotMean-1  \
# 0                    73.7686           35.0659        82.3580   1502.760
# 1                    73.7262           34.9930        83.0070   1521.620
# 2                    73.6839           34.9201        83.6560   1512.130
# 3                    73.6415           34.8472        84.3050   1488.260
# 4                    73.5991           34.7743        84.9540   1494.730
# ...                      ...               ...            ...        ...
# 42619                72.8500           29.0079        50.6938    532.308
# 42620                72.7006           29.0459        51.2225    538.059
# 42621                72.4397           29.0839        51.7513    655.092
# 42622                72.1787           29.1219        52.2800    724.791
# 42623                71.9178           29.1599        52.8088    638.085
#
#        VelRotorMean-1  TempEjeLento_1
# 0             17.7552       22.880098
# 1             17.0368       22.880692
# 2             17.3090       22.881285
# 3             16.8005       22.881875
# 4             16.6559       22.882463
# ...               ...             ...
# 42619         15.5693       22.365700
# 42620         15.8019       22.493200
# 42621         16.6070       22.582200
# 42622         17.0285       22.666800
# 42623         16.1602       22.751400
#
# [42624 rows x 9 columns]

# %%
validation=train_tv.loc[round(longitud):len(train_tv)]
validation.reset_index(drop=True, inplace=True)
validation
# Out:
#                date_time  TempEjeLento_1-1  TempAmbMean-1  \
# 0    2017-11-29 00:00:00           22.7514       10.88510
# 1    2017-11-29 00:10:00           22.8360       10.88770
# 2    2017-11-29 00:20:00           22.9152       10.89020
# 3    2017-11-29 00:30:00           22.9417       10.89280
# 4    2017-11-29 00:40:00           22.9549       10.89540
# ...                  ...               ...            ...
# 4747 2017-12-31 23:10:00           20.2618        8.34259
# 4748 2017-12-31 23:20:00           20.1293        8.27274
# 4749 2017-12-31 23:30:00           19.8581        8.20288
# 4750 2017-12-31 23:40:00           19.5864        8.13303
# 4751 2017-12-31 23:50:00           19.3147        8.06317
#
#       TempRodamMultipMean-1  TempCojLOAMean-1  TempGenMean-1   PotMean-1  \
# 0                   71.6569           29.1979        53.3376  731.328000
# 1                   71.3959           29.1589        53.8663  743.456000
# 2                   71.1350           29.1927        54.3951  487.361000
# 3                   70.8741           29.2266        54.7146  603.615000
# 4                   70.6131           29.2604        54.8153  551.536000
# ...                     ...               ...            ...         ...
# 4747                58.4853           31.6632        79.7916   83.266200
# 4748                56.0265           31.4196        78.4111    0.044976
# 4749                53.5842           31.1759        77.0307    0.094435
# 4750                51.1418           30.9322        75.6502    0.143894
# 4751                48.6994           30.6886        74.2697    0.193353
#
#       VelRotorMean-1  TempEjeLento_1
# 0          17.103700         22.8360
# 1          16.813000         22.9152
# 2          15.450100         22.9417
# 3          16.145600         22.9549
# 4          15.615300         22.9682
# ...              ...             ...
# 4747        2.821730         20.1293
# 4748        0.367458         19.8581
# 4749        0.481486         19.5864
# 4750        0.275624         19.3147
# 4751        0.414054         19.0430
#
# [4752 rows x 9 columns]

# %%
test=datos_listos.copy()
mask = ((test['date_time'] >= '2018-01-01 00:00:00') & (test['date_time'] < '2018-12-01 00:00:00')) 
test=test.loc[mask]
test.reset_index(drop=True, inplace=True)
test
# Out:
#                 date_time  TempEjeLento_1-1  TempAmbMean-1  \
# 0     2018-01-01 00:00:00           19.0430        7.99331
# 1     2018-01-01 00:10:00           18.7970        7.92346
# 2     2018-01-01 00:20:00           18.6419        7.85360
# 3     2018-01-01 00:30:00           18.4947        7.78375
# 4     2018-01-01 00:40:00           18.3476        7.71389
# ...                   ...               ...            ...
# 48091 2018-11-30 23:10:00           18.4543        6.04839
# 48092 2018-11-30 23:20:00           18.4170        5.99709
# 48093 2018-11-30 23:30:00           18.3798        5.94744
# 48094 2018-11-30 23:40:00           18.3346        5.92394
# 48095 2018-11-30 23:50:00           18.2666        5.90944
#
#        TempRodamMultipMean-1  TempCojLOAMean-1  TempGenMean-1  PotMean-1  \
# 0                    46.8007           30.4449        72.8892   0.242812
# 1                    46.2656           30.2012        71.5087   0.292271
# 2                    45.7959           29.9576        70.1282   0.341730
# 3                    45.3262           29.7139        68.7477   0.391189
# 4                    44.8565           29.4703        67.3672   0.440648
# ...                      ...               ...            ...        ...
# 48091                52.5553           23.4519        42.6439  59.172800
# 48092                52.3561           23.4182        42.6022  73.653900
# 48093                52.1570           23.3844        42.5605  62.996200
# 48094                51.9578           23.3507        42.5188  45.085900
# 48095                51.7586           23.3169        42.4771  48.403300
#
#        VelRotorMean-1  TempEjeLento_1
# 0            0.231295         18.7970
# 1            0.332392         18.6419
# 2            0.379906         18.4947
# 3            0.000000         18.3476
# 4            0.000000         18.2004
# ...               ...             ...
# 48091       11.642600         18.4170
# 48092       11.672200         18.3798
# 48093       11.703200         18.3346
# 48094       11.694900         18.2666
# 48095       11.683900         18.1971
#
# [48096 rows x 9 columns]

# %%
from numpy import array
from numpy import hstack

def datosstack(data):
    
        X1 = array(data['TempAmbMean-1'])
        X2 = array(data['TempRodamMultipMean-1'])
        #X3 = array(data['TempCojLAMean-1'])
        X3 = array(data['TempCojLOAMean-1'])
        X4 = array(data['TempGenMean-1'])
        X5 = array(data['PotMean-1'])
        X6 = array(data['VelRotorMean-1'])
        X7 = array(data['TempEjeLento_1-1'])
        X8 = array(data['TempEjeLento_1'])

        X1 = X1.reshape((len(X1), 1))
        X2 = X2.reshape((len(X2), 1))
        X3 = X3.reshape((len(X3), 1))
        X4 = X4.reshape((len(X4), 1))
        X5 = X5.reshape((len(X5), 1))
        X6 = X6.reshape((len(X6), 1))
        X7 = X7.reshape((len(X7), 1))
        X8 = X8.reshape((len(X8), 1))
        #X9 = X8.reshape((len(X9), 1))
        
        dataset = hstack((X1, X2, X3, X4, X5, X6, X7, X8))            

        return dataset

# %%
dataset_train=datosstack(training)
dataset_validation=datosstack(validation)
dataset_test=datosstack(test)

dataset_train.shape
# Out:
# (42624, 8)

# %%
def split_sequences(sequences, n_steps):
	X, y = list(), list()
	for i in range(len(sequences)):
		# find the end of this pattern
		#end_ix = n_steps*i + n_steps
		end_ix = i + n_steps
		#start_ix = end_ix - n_steps
		# check if we are beyond the dataset
		if end_ix > len(sequences):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1, -1]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %% [markdown]
# Datos de Entrenamiento

# %%
n_steps = 144
xtrain, ytrain = split_sequences(dataset_train, n_steps)
print(xtrain.shape, ytrain.shape)
# Out:
# (42481, 144, 7) (42481,)

# %% [markdown]
# Datos de Validación

# %%
xvalidation, yvalidation = split_sequences(dataset_validation, n_steps)
print(xvalidation.shape, yvalidation.shape)
# Out:
# (4609, 144, 7) (4609,)

# %% [markdown]
# Datos de prueba

# %%
xtest, ytest = split_sequences(dataset_test, n_steps)
print(xtest.shape, ytest.shape)
# Out:
# (47953, 144, 7) (47953,)

# %% [markdown]
# # Creación del Modelo

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)
    return keras.Model(inputs, outputs)

# %% [markdown]
# ## Entrenamiento del Modelo

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
input_shape = xtrain.shape[1:]

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=5,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.3,
)

model.compile(
    loss="mean_squared_error",
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    metrics=[keras.metrics.Accuracy()]
)
#model.summary()

callbacks = [keras.callbacks.EarlyStopping(patience=50, restore_best_weights=True)]

history = model.fit(
    xtrain,
    ytrain,
    validation_split=0.2,
    epochs=200,
    batch_size=64,
    callbacks=callbacks,
)

model.evaluate(xvalidation, yvalidation, verbose=1)
# Out:
# Epoch 1/200
# 531/531 [==============================] - 145s 257ms/step - loss: 557.3659 - accuracy: 0.0000e+00 - val_loss: 14.3926 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 531/531 [==============================] - 99s 187ms/step - loss: 60.9662 - accuracy: 0.0000e+00 - val_loss: 5.1233 - val_accuracy: 0.0000e+00
# Epoch 3/200
# 531/531 [==============================] - 86s 162ms/step - loss: 47.6413 - accuracy: 0.0000e+00 - val_loss: 15.0517 - val_accuracy: 0.0000e+00
# Epoch 4/200
# 531/531 [==============================] - 87s 163ms/step - loss: 44.3033 - accuracy: 0.0000e+00 - val_loss: 4.7586 - val_accuracy: 0.0000e+00
# Epoch 5/200
# 531/531 [==============================] - 87s 163ms/step - loss: 40.5892 - accuracy: 0.0000e+00 - val_loss: 2.3532 - val_accuracy: 0.0000e+00
# Epoch 6/200
# 531/531 [==============================] - 87s 164ms/step - loss: 38.2060 - accuracy: 0.0000e+00 - val_loss: 3.4939 - val_accuracy: 0.0000e+00
# Epoch 7/200
# 531/531 [==============================] - 87s 164ms/step - loss: 37.0224 - accuracy: 0.0000e+00 - val_loss: 1.6422 - val_accuracy: 0.0000e+00
# Epoch 8/200
# 531/531 [==============================] - 87s 164ms/step - loss: 35.7154 - accuracy: 0.0000e+00 - val_loss: 4.0168 - val_accuracy: 0.0000e+00
# Epoch 9/200
# 531/531 [==============================] - 87s 164ms/step - loss: 34.6807 - accuracy: 0.0000e+00 - val_loss: 3.3961 - val_accuracy: 0.0000e+00
# Epoch 10/200
# 531/531 [==============================] - 88s 165ms/step - loss: 34.1048 - accuracy: 0.0000e+00 - val_loss: 1.3569 - val_accuracy: 0.0000e+00
# Epoch 11/200
# 531/531 [==============================] - 86s 162ms/step - loss: 32.4137 - accuracy: 0.0000e+00 - val_loss: 4.3494 - val_accuracy: 0.0000e+00
# Epoch 12/200
# 531/531 [==============================] - 87s 163ms/step - loss: 31.3221 - accuracy: 0.0000e+00 - val_loss: 3.3148 - val_accuracy: 0.0000e+00
# Epoch 13/200
# 531/531 [==============================] - 89s 168ms/step - loss: 29.7311 - accuracy: 0.0000e+00 - val_loss: 3.7007 - val_accuracy: 0.0000e+00
# Epoch 14/200
# 531/531 [==============================] - 85s 160ms/step - loss: 27.8429 - accuracy: 0.0000e+00 - val_loss: 2.9772 - val_accuracy: 0.0000e+00
# Epoch 15/200
# 531/531 [==============================] - 85s 160ms/step - loss: 25.9754 - accuracy: 0.0000e+00 - val_loss: 6.4631 - val_accuracy: 0.0000e+00
# Epoch 16/200
# 531/531 [==============================] - 85s 160ms/step - loss: 24.5378 - accuracy: 0.0000e+00 - val_loss: 2.9248 - val_accuracy: 0.0000e+00
# Epoch 17/200
# 531/531 [==============================] - 85s 161ms/step - loss: 23.7050 - accuracy: 0.0000e+00 - val_loss: 4.8212 - val_accuracy: 0.0000e+00
# Epoch 18/200
# 531/531 [==============================] - 85s 160ms/step - loss: 22.9261 - accuracy: 0.0000e+00 - val_loss: 1.6737 - val_accuracy: 0.0000e+00
# Epoch 19/200
# 531/531 [==============================] - 85s 160ms/step - loss: 22.2968 - accuracy: 0.0000e+00 - val_loss: 1.2363 - val_accuracy: 0.0000e+00
# Epoch 20/200
# 531/531 [==============================] - 228s 430ms/step - loss: 21.5118 - accuracy: 0.0000e+00 - val_loss: 2.9878 - val_accuracy: 0.0000e+00
# Epoch 21/200
# 531/531 [==============================] - 68s 128ms/step - loss: 20.2188 - accuracy: 0.0000e+00 - val_loss: 0.8681 - val_accuracy: 0.0000e+00
# Epoch 22/200
# 531/531 [==============================] - 78s 147ms/step - loss: 19.5365 - accuracy: 0.0000e+00 - val_loss: 0.9344 - val_accuracy: 0.0000e+00
# Epoch 23/200
# 531/531 [==============================] - 79s 149ms/step - loss: 19.0704 - accuracy: 0.0000e+00 - val_loss: 1.5860 - val_accuracy: 0.0000e+00
# Epoch 24/200
# 531/531 [==============================] - 81s 153ms/step - loss: 18.4185 - accuracy: 0.0000e+00 - val_loss: 0.9396 - val_accuracy: 0.0000e+00
# Epoch 25/200
# 531/531 [==============================] - 80s 151ms/step - loss: 18.1470 - accuracy: 0.0000e+00 - val_loss: 2.7799 - val_accuracy: 0.0000e+00
# Epoch 26/200
# 531/531 [==============================] - 80s 151ms/step - loss: 17.0875 - accuracy: 0.0000e+00 - val_loss: 1.2194 - val_accuracy: 0.0000e+00
# Epoch 27/200
# 531/531 [==============================] - 80s 151ms/step - loss: 16.6848 - accuracy: 0.0000e+00 - val_loss: 2.4617 - val_accuracy: 0.0000e+00
# Epoch 28/200
# 531/531 [==============================] - 81s 152ms/step - loss: 14.8683 - accuracy: 0.0000e+00 - val_loss: 0.9223 - val_accuracy: 0.0000e+00
# Epoch 29/200
# 531/531 [==============================] - 82s 155ms/step - loss: 14.1589 - accuracy: 0.0000e+00 - val_loss: 0.9602 - val_accuracy: 0.0000e+00
# Epoch 30/200
# 531/531 [==============================] - 82s 155ms/step - loss: 13.5295 - accuracy: 0.0000e+00 - val_loss: 10.3237 - val_accuracy: 0.0000e+00
# Epoch 31/200
# 531/531 [==============================] - 82s 155ms/step - loss: 13.3476 - accuracy: 0.0000e+00 - val_loss: 2.4301 - val_accuracy: 0.0000e+00
# Epoch 32/200
# 531/531 [==============================] - 82s 155ms/step - loss: 12.5681 - accuracy: 0.0000e+00 - val_loss: 1.7622 - val_accuracy: 0.0000e+00
# Epoch 33/200
# 531/531 [==============================] - 82s 155ms/step - loss: 12.1062 - accuracy: 0.0000e+00 - val_loss: 1.8124 - val_accuracy: 0.0000e+00
# Epoch 34/200
# 531/531 [==============================] - 83s 155ms/step - loss: 11.4676 - accuracy: 0.0000e+00 - val_loss: 0.9160 - val_accuracy: 0.0000e+00
# Epoch 35/200
# 531/531 [==============================] - 3471s 7s/step - loss: 11.2274 - accuracy: 0.0000e+00 - val_loss: 1.7793 - val_accuracy: 0.0000e+00
# Epoch 36/200
# 531/531 [==============================] - 67s 126ms/step - loss: 11.0700 - accuracy: 0.0000e+00 - val_loss: 0.7980 - val_accuracy: 0.0000e+00
# Epoch 37/200
# 531/531 [==============================] - 75s 142ms/step - loss: 10.7692 - accuracy: 0.0000e+00 - val_loss: 1.0784 - val_accuracy: 0.0000e+00
# Epoch 38/200
# 531/531 [==============================] - 79s 148ms/step - loss: 10.2988 - accuracy: 0.0000e+00 - val_loss: 0.9302 - val_accuracy: 0.0000e+00
# Epoch 39/200
# 531/531 [==============================] - 79s 149ms/step - loss: 9.9991 - accuracy: 0.0000e+00 - val_loss: 1.1289 - val_accuracy: 0.0000e+00
# Epoch 40/200
# 531/531 [==============================] - 81s 153ms/step - loss: 9.3782 - accuracy: 2.9426e-05 - val_loss: 1.2354 - val_accuracy: 0.0000e+00
# Epoch 41/200
# 531/531 [==============================] - 83s 156ms/step - loss: 8.4520 - accuracy: 0.0000e+00 - val_loss: 2.2396 - val_accuracy: 0.0000e+00
# Epoch 42/200
# 531/531 [==============================] - 83s 157ms/step - loss: 7.1536 - accuracy: 0.0000e+00 - val_loss: 1.2141 - val_accuracy: 0.0000e+00
# Epoch 43/200
# 531/531 [==============================] - 83s 157ms/step - loss: 6.4799 - accuracy: 0.0000e+00 - val_loss: 0.8032 - val_accuracy: 0.0000e+00
# Epoch 44/200
# 531/531 [==============================] - 83s 157ms/step - loss: 5.7138 - accuracy: 0.0000e+00 - val_loss: 0.8319 - val_accuracy: 0.0000e+00
# Epoch 45/200
# 531/531 [==============================] - 83s 157ms/step - loss: 5.4598 - accuracy: 0.0000e+00 - val_loss: 1.1449 - val_accuracy: 0.0000e+00
# Epoch 46/200
# 531/531 [==============================] - 83s 157ms/step - loss: 5.0510 - accuracy: 0.0000e+00 - val_loss: 0.9222 - val_accuracy: 0.0000e+00
# Epoch 47/200
# 531/531 [==============================] - 2590s 5s/step - loss: 4.9875 - accuracy: 0.0000e+00 - val_loss: 1.2837 - val_accuracy: 0.0000e+00
# Epoch 48/200
# 531/531 [==============================] - 68s 128ms/step - loss: 4.5112 - accuracy: 0.0000e+00 - val_loss: 0.6872 - val_accuracy: 0.0000e+00
# Epoch 49/200
# 531/531 [==============================] - 81s 153ms/step - loss: 4.2231 - accuracy: 0.0000e+00 - val_loss: 0.6218 - val_accuracy: 0.0000e+00
# Epoch 50/200
# 531/531 [==============================] - 81s 153ms/step - loss: 3.9835 - accuracy: 0.0000e+00 - val_loss: 0.6882 - val_accuracy: 0.0000e+00
# Epoch 51/200
# 531/531 [==============================] - 82s 154ms/step - loss: 3.8606 - accuracy: 0.0000e+00 - val_loss: 0.8381 - val_accuracy: 0.0000e+00
# Epoch 52/200
# 531/531 [==============================] - 83s 155ms/step - loss: 3.6042 - accuracy: 0.0000e+00 - val_loss: 0.7358 - val_accuracy: 0.0000e+00
# Epoch 53/200
# 531/531 [==============================] - 83s 157ms/step - loss: 3.2877 - accuracy: 0.0000e+00 - val_loss: 0.7223 - val_accuracy: 0.0000e+00
# Epoch 54/200
# 531/531 [==============================] - 83s 156ms/step - loss: 3.1425 - accuracy: 0.0000e+00 - val_loss: 0.5791 - val_accuracy: 0.0000e+00
# Epoch 55/200
# 531/531 [==============================] - 83s 157ms/step - loss: 3.0357 - accuracy: 0.0000e+00 - val_loss: 0.5182 - val_accuracy: 0.0000e+00
# Epoch 56/200
# 531/531 [==============================] - 83s 156ms/step - loss: 2.9014 - accuracy: 0.0000e+00 - val_loss: 0.6103 - val_accuracy: 0.0000e+00
# Epoch 57/200
# 531/531 [==============================] - 82s 155ms/step - loss: 2.7726 - accuracy: 0.0000e+00 - val_loss: 0.9418 - val_accuracy: 0.0000e+00
# Epoch 58/200
# 531/531 [==============================] - 82s 155ms/step - loss: 2.7473 - accuracy: 0.0000e+00 - val_loss: 1.0831 - val_accuracy: 0.0000e+00
# Epoch 59/200
# 531/531 [==============================] - 83s 157ms/step - loss: 2.5403 - accuracy: 0.0000e+00 - val_loss: 0.4834 - val_accuracy: 0.0000e+00
# Epoch 60/200
# 531/531 [==============================] - 82s 155ms/step - loss: 2.4164 - accuracy: 0.0000e+00 - val_loss: 0.5529 - val_accuracy: 0.0000e+00
# Epoch 61/200
# 531/531 [==============================] - 82s 155ms/step - loss: 2.4612 - accuracy: 0.0000e+00 - val_loss: 0.5566 - val_accuracy: 0.0000e+00
# Epoch 62/200
# 531/531 [==============================] - 83s 156ms/step - loss: 2.3432 - accuracy: 0.0000e+00 - val_loss: 0.5635 - val_accuracy: 0.0000e+00
# Epoch 63/200
# 531/531 [==============================] - 83s 157ms/step - loss: 2.2603 - accuracy: 0.0000e+00 - val_loss: 0.5881 - val_accuracy: 0.0000e+00
# Epoch 64/200
# 531/531 [==============================] - 82s 155ms/step - loss: 2.2726 - accuracy: 0.0000e+00 - val_loss: 0.7293 - val_accuracy: 0.0000e+00
# Epoch 65/200
# 531/531 [==============================] - 82s 155ms/step - loss: 2.1108 - accuracy: 0.0000e+00 - val_loss: 0.6633 - val_accuracy: 0.0000e+00
# Epoch 66/200
# 531/531 [==============================] - 83s 156ms/step - loss: 2.1128 - accuracy: 0.0000e+00 - val_loss: 0.9279 - val_accuracy: 0.0000e+00
# Epoch 67/200
# 531/531 [==============================] - 82s 154ms/step - loss: 2.0129 - accuracy: 0.0000e+00 - val_loss: 0.9468 - val_accuracy: 0.0000e+00
# Epoch 68/200
# 531/531 [==============================] - 82s 155ms/step - loss: 1.9871 - accuracy: 0.0000e+00 - val_loss: 0.9882 - val_accuracy: 0.0000e+00
# Epoch 69/200
# 531/531 [==============================] - 82s 155ms/step - loss: 1.9824 - accuracy: 0.0000e+00 - val_loss: 0.5004 - val_accuracy: 0.0000e+00
# Epoch 70/200
# 531/531 [==============================] - 83s 155ms/step - loss: 1.9055 - accuracy: 0.0000e+00 - val_loss: 0.5543 - val_accuracy: 0.0000e+00
# Epoch 71/200
# 531/531 [==============================] - 86s 163ms/step - loss: 1.8264 - accuracy: 0.0000e+00 - val_loss: 0.5629 - val_accuracy: 0.0000e+00
# Epoch 72/200
# 531/531 [==============================] - 83s 156ms/step - loss: 1.8021 - accuracy: 0.0000e+00 - val_loss: 0.4636 - val_accuracy: 0.0000e+00
# Epoch 73/200
# 531/531 [==============================] - 83s 156ms/step - loss: 1.7462 - accuracy: 0.0000e+00 - val_loss: 0.5389 - val_accuracy: 0.0000e+00
# Epoch 74/200
# 531/531 [==============================] - 82s 155ms/step - loss: 1.7566 - accuracy: 0.0000e+00 - val_loss: 0.5338 - val_accuracy: 0.0000e+00
# Epoch 75/200
# 531/531 [==============================] - 90s 169ms/step - loss: 1.7292 - accuracy: 0.0000e+00 - val_loss: 0.5044 - val_accuracy: 0.0000e+00
# Epoch 76/200
# 531/531 [==============================] - 84s 158ms/step - loss: 1.6548 - accuracy: 0.0000e+00 - val_loss: 0.4122 - val_accuracy: 0.0000e+00
# Epoch 77/200
# 531/531 [==============================] - 83s 156ms/step - loss: 1.6149 - accuracy: 0.0000e+00 - val_loss: 0.4511 - val_accuracy: 0.0000e+00
# Epoch 78/200
# 531/531 [==============================] - 84s 158ms/step - loss: 1.5627 - accuracy: 0.0000e+00 - val_loss: 0.5346 - val_accuracy: 0.0000e+00
# Epoch 79/200
# 531/531 [==============================] - 84s 158ms/step - loss: 1.5964 - accuracy: 0.0000e+00 - val_loss: 0.4576 - val_accuracy: 0.0000e+00
# Epoch 80/200
# 531/531 [==============================] - 85s 160ms/step - loss: 1.5213 - accuracy: 0.0000e+00 - val_loss: 0.5988 - val_accuracy: 0.0000e+00
# Epoch 81/200
# 531/531 [==============================] - 86s 162ms/step - loss: 1.4962 - accuracy: 0.0000e+00 - val_loss: 0.5329 - val_accuracy: 0.0000e+00
# Epoch 82/200
# 531/531 [==============================] - 83s 156ms/step - loss: 1.5106 - accuracy: 0.0000e+00 - val_loss: 0.5562 - val_accuracy: 0.0000e+00
# Epoch 83/200
# 531/531 [==============================] - 84s 158ms/step - loss: 1.4888 - accuracy: 0.0000e+00 - val_loss: 0.4465 - val_accuracy: 0.0000e+00
# Epoch 84/200
# 531/531 [==============================] - 83s 157ms/step - loss: 1.3856 - accuracy: 0.0000e+00 - val_loss: 0.4509 - val_accuracy: 0.0000e+00
# Epoch 85/200
# 531/531 [==============================] - 84s 158ms/step - loss: 1.4252 - accuracy: 0.0000e+00 - val_loss: 0.4347 - val_accuracy: 0.0000e+00
# Epoch 86/200
# 531/531 [==============================] - 85s 161ms/step - loss: 1.3527 - accuracy: 0.0000e+00 - val_loss: 0.5368 - val_accuracy: 0.0000e+00
# Epoch 87/200
# 531/531 [==============================] - 83s 157ms/step - loss: 1.4089 - accuracy: 0.0000e+00 - val_loss: 0.4489 - val_accuracy: 0.0000e+00
# Epoch 88/200
# 531/531 [==============================] - 89s 168ms/step - loss: 1.3295 - accuracy: 0.0000e+00 - val_loss: 0.5104 - val_accuracy: 0.0000e+00
# Epoch 89/200
# 531/531 [==============================] - 95s 180ms/step - loss: 1.2973 - accuracy: 0.0000e+00 - val_loss: 0.4505 - val_accuracy: 0.0000e+00
# Epoch 90/200
# 531/531 [==============================] - 87s 164ms/step - loss: 1.2941 - accuracy: 0.0000e+00 - val_loss: 0.7380 - val_accuracy: 0.0000e+00
# Epoch 91/200
# 531/531 [==============================] - 83s 156ms/step - loss: 1.2311 - accuracy: 0.0000e+00 - val_loss: 0.3965 - val_accuracy: 0.0000e+00
# Epoch 92/200
# 531/531 [==============================] - 84s 159ms/step - loss: 1.2485 - accuracy: 0.0000e+00 - val_loss: 0.4759 - val_accuracy: 0.0000e+00
# Epoch 93/200
# 531/531 [==============================] - 84s 157ms/step - loss: 1.2501 - accuracy: 0.0000e+00 - val_loss: 0.9998 - val_accuracy: 0.0000e+00
# Epoch 94/200
# 531/531 [==============================] - 84s 158ms/step - loss: 1.2547 - accuracy: 0.0000e+00 - val_loss: 0.6241 - val_accuracy: 0.0000e+00
# Epoch 95/200
# 531/531 [==============================] - 84s 158ms/step - loss: 1.2205 - accuracy: 0.0000e+00 - val_loss: 0.3937 - val_accuracy: 0.0000e+00
# Epoch 96/200
# 531/531 [==============================] - 84s 158ms/step - loss: 1.1802 - accuracy: 0.0000e+00 - val_loss: 0.4570 - val_accuracy: 0.0000e+00
# Epoch 97/200
# 531/531 [==============================] - 84s 158ms/step - loss: 1.1961 - accuracy: 0.0000e+00 - val_loss: 0.6131 - val_accuracy: 0.0000e+00
# Epoch 98/200
# 531/531 [==============================] - 118s 223ms/step - loss: 1.1129 - accuracy: 0.0000e+00 - val_loss: 0.4114 - val_accuracy: 0.0000e+00
# Epoch 99/200
# 531/531 [==============================] - 84s 158ms/step - loss: 1.1720 - accuracy: 0.0000e+00 - val_loss: 0.3689 - val_accuracy: 0.0000e+00
# Epoch 100/200
# 531/531 [==============================] - 223s 420ms/step - loss: 1.1557 - accuracy: 0.0000e+00 - val_loss: 0.5768 - val_accuracy: 0.0000e+00
# Epoch 101/200
# 531/531 [==============================] - 416s 784ms/step - loss: 1.1376 - accuracy: 0.0000e+00 - val_loss: 0.5019 - val_accuracy: 0.0000e+00
# Epoch 102/200
# 531/531 [==============================] - 92s 173ms/step - loss: 1.0780 - accuracy: 0.0000e+00 - val_loss: 0.3819 - val_accuracy: 0.0000e+00
# Epoch 103/200
# 531/531 [==============================] - 100s 189ms/step - loss: 1.0750 - accuracy: 2.9426e-05 - val_loss: 0.3943 - val_accuracy: 0.0000e+00
# Epoch 104/200
# 531/531 [==============================] - 86s 163ms/step - loss: 1.0748 - accuracy: 0.0000e+00 - val_loss: 0.5796 - val_accuracy: 0.0000e+00
# Epoch 105/200
# 531/531 [==============================] - 87s 163ms/step - loss: 1.0966 - accuracy: 0.0000e+00 - val_loss: 0.4616 - val_accuracy: 0.0000e+00
# Epoch 106/200
# 531/531 [==============================] - 86s 162ms/step - loss: 1.0362 - accuracy: 0.0000e+00 - val_loss: 0.3838 - val_accuracy: 0.0000e+00
# Epoch 107/200
# 531/531 [==============================] - 87s 163ms/step - loss: 1.0269 - accuracy: 2.9426e-05 - val_loss: 0.4217 - val_accuracy: 0.0000e+00
# Epoch 108/200
# 531/531 [==============================] - 87s 163ms/step - loss: 1.0007 - accuracy: 0.0000e+00 - val_loss: 0.8934 - val_accuracy: 0.0000e+00
# Epoch 109/200
# 531/531 [==============================] - 86s 163ms/step - loss: 1.0268 - accuracy: 0.0000e+00 - val_loss: 0.3954 - val_accuracy: 0.0000e+00
# Epoch 110/200
# 531/531 [==============================] - 87s 163ms/step - loss: 0.9903 - accuracy: 0.0000e+00 - val_loss: 0.3720 - val_accuracy: 0.0000e+00
# Epoch 111/200
# 531/531 [==============================] - 87s 163ms/step - loss: 0.9945 - accuracy: 0.0000e+00 - val_loss: 0.3868 - val_accuracy: 0.0000e+00
# Epoch 112/200
# 531/531 [==============================] - 88s 166ms/step - loss: 0.9821 - accuracy: 0.0000e+00 - val_loss: 0.3518 - val_accuracy: 0.0000e+00
# Epoch 113/200
# 531/531 [==============================] - 87s 165ms/step - loss: 0.9729 - accuracy: 0.0000e+00 - val_loss: 0.6851 - val_accuracy: 0.0000e+00
# Epoch 114/200
# 531/531 [==============================] - 87s 163ms/step - loss: 0.9618 - accuracy: 0.0000e+00 - val_loss: 0.4978 - val_accuracy: 0.0000e+00
# Epoch 115/200
# 531/531 [==============================] - 87s 163ms/step - loss: 0.9553 - accuracy: 0.0000e+00 - val_loss: 0.4729 - val_accuracy: 0.0000e+00
# Epoch 116/200
# 531/531 [==============================] - 87s 163ms/step - loss: 0.9445 - accuracy: 0.0000e+00 - val_loss: 0.4332 - val_accuracy: 0.0000e+00
# Epoch 117/200
# 531/531 [==============================] - 88s 166ms/step - loss: 0.9165 - accuracy: 0.0000e+00 - val_loss: 0.6130 - val_accuracy: 0.0000e+00
# Epoch 118/200
# 531/531 [==============================] - 87s 165ms/step - loss: 0.8816 - accuracy: 0.0000e+00 - val_loss: 0.3217 - val_accuracy: 0.0000e+00
# Epoch 119/200
# 531/531 [==============================] - 98s 184ms/step - loss: 0.9554 - accuracy: 0.0000e+00 - val_loss: 0.3721 - val_accuracy: 0.0000e+00
# Epoch 120/200
# 531/531 [==============================] - 98s 184ms/step - loss: 0.9201 - accuracy: 0.0000e+00 - val_loss: 0.8187 - val_accuracy: 0.0000e+00
# Epoch 121/200
# 531/531 [==============================] - 88s 166ms/step - loss: 0.8940 - accuracy: 0.0000e+00 - val_loss: 0.6393 - val_accuracy: 0.0000e+00
# Epoch 122/200
# 531/531 [==============================] - 87s 164ms/step - loss: 0.8940 - accuracy: 0.0000e+00 - val_loss: 0.3965 - val_accuracy: 0.0000e+00
# Epoch 123/200
# 531/531 [==============================] - 87s 164ms/step - loss: 0.8670 - accuracy: 0.0000e+00 - val_loss: 0.4981 - val_accuracy: 0.0000e+00
# Epoch 124/200
# 531/531 [==============================] - 86s 162ms/step - loss: 0.8587 - accuracy: 0.0000e+00 - val_loss: 0.7258 - val_accuracy: 0.0000e+00
# Epoch 125/200
# 531/531 [==============================] - 87s 163ms/step - loss: 0.8772 - accuracy: 0.0000e+00 - val_loss: 0.7551 - val_accuracy: 0.0000e+00
# Epoch 126/200
# 531/531 [==============================] - 87s 163ms/step - loss: 0.8643 - accuracy: 0.0000e+00 - val_loss: 0.5698 - val_accuracy: 1.1769e-04
# Epoch 127/200
# 531/531 [==============================] - 89s 169ms/step - loss: 0.8362 - accuracy: 0.0000e+00 - val_loss: 0.9753 - val_accuracy: 0.0000e+00
# Epoch 128/200
# 531/531 [==============================] - 88s 166ms/step - loss: 0.8485 - accuracy: 2.9426e-05 - val_loss: 0.6190 - val_accuracy: 0.0000e+00
# Epoch 129/200
# 531/531 [==============================] - 88s 166ms/step - loss: 0.8353 - accuracy: 0.0000e+00 - val_loss: 0.5037 - val_accuracy: 0.0000e+00
# Epoch 130/200
# 531/531 [==============================] - 89s 167ms/step - loss: 0.8285 - accuracy: 0.0000e+00 - val_loss: 0.3600 - val_accuracy: 0.0000e+00
# Epoch 131/200
# 531/531 [==============================] - 88s 166ms/step - loss: 0.8333 - accuracy: 0.0000e+00 - val_loss: 0.2851 - val_accuracy: 0.0000e+00
# Epoch 132/200
# 531/531 [==============================] - 87s 165ms/step - loss: 0.8130 - accuracy: 0.0000e+00 - val_loss: 0.8587 - val_accuracy: 0.0000e+00
# Epoch 133/200
# 531/531 [==============================] - 89s 167ms/step - loss: 0.8054 - accuracy: 0.0000e+00 - val_loss: 1.1922 - val_accuracy: 0.0000e+00
# Epoch 134/200
#  34/531 [>.............................] - ETA: 1:18 - loss: 0.7619 - accuracy: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [32], in <cell line: 23>()
#      19 #model.summary()
#      21 callbacks = [keras.callbacks.EarlyStopping(patience=50, restore_best_weights=True)]
# ---> 23 history = model.fit(
#      24     xtrain,
#      25     ytrain,
#      26     validation_split=0.2,
#      27     epochs=200,
#      28     batch_size=64,
#      29     callbacks=callbacks,
#      30 )
#      32 model.evaluate(xvalidation, yvalidation, verbose=1)
#
# File D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\engine\training.py:1414, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1412 logs = tmp_logs  # No error, now safe to assign to logs.
#    1413 end_step = step + data_handler.step_increment
# -> 1414 callbacks.on_train_batch_end(end_step, logs)
#    1415 if self.stop_training:
#    1416   break
#
# File D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\callbacks.py:438, in CallbackList.on_train_batch_end(self, batch, logs)
#     431 """Calls the `on_train_batch_end` methods of its callbacks.
#     432
#     433 Args:
#     434     batch: Integer, index of batch within the current epoch.
#     435     logs: Dict. Aggregated metric results up until this batch.
#     436 """
#     437 if self._should_call_train_batch_hooks:
# --> 438   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\callbacks.py:297, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     295   self._call_batch_begin_hook(mode, batch, logs)
#     296 elif hook == 'end':
# --> 297   self._call_batch_end_hook(mode, batch, logs)
#     298 else:
#     299   raise ValueError(
#     300       f'Unrecognized hook: {hook}. Expected values are ["begin", "end"]')
#
# File D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\callbacks.py:318, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     315   batch_time = time.time() - self._batch_start_time
#     316   self._batch_times.append(batch_time)
# --> 318 self._call_batch_hook_helper(hook_name, batch, logs)
#     320 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     321   end_hook_name = hook_name
#
# File D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\callbacks.py:356, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     354 for callback in self.callbacks:
#     355   hook = getattr(callback, hook_name)
# --> 356   hook(batch, logs)
#     358 if self._check_timing:
#     359   if hook_name not in self._hook_times:
#
# File D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\callbacks.py:1034, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1033 def on_train_batch_end(self, batch, logs=None):
# -> 1034   self._batch_update_progbar(batch, logs)
#
# File D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\callbacks.py:1107, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1104 if self.verbose == 1:
#    1105   # Only block async when verbose = 1.
#    1106   logs = tf_utils.sync_to_numpy_or_python_type(logs)
# -> 1107   self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\utils\generic_utils.py:976, in Progbar.update(self, current, values, finalize)
#     973     info += '\n'
#     975   message += info
# --> 976   io_utils.print_msg(message, line_break=False)
#     977   message = ''
#     979 elif self.verbose == 2:
#
# File D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\utils\io_utils.py:78, in print_msg(message, line_break)
#      76   else:
#      77     sys.stdout.write(message)
# ---> 78   sys.stdout.flush()
#      79 else:
#      80   logging.info(message)
#
# File D:\Anaconda\envs\tf-gpu\lib\site-packages\ipykernel\iostream.py:475, in OutStream.flush(self)
#     464 """trigger actual zmq send
#     465
#     466 send will happen in the background thread
#     467 """
#     468 if (
#     469     self.pub_thread
#     470     and self.pub_thread.thread is not None
#    (...)
#     473 ):
#     474     # request flush on the background thread
# --> 475     self.pub_thread.schedule(self._flush)
#     476     # wait for flush to actually get through, if we can.
#     477     evt = threading.Event()
#
# File D:\Anaconda\envs\tf-gpu\lib\site-packages\ipykernel\iostream.py:210, in IOPubThread.schedule(self, f)
#     208     self._events.append(f)
#     209     # wake event thread (message content is ignored)
# --> 210     self._event_pipe.send(b"")
#     211 else:
#     212     f()
#
# File D:\Anaconda\envs\tf-gpu\lib\site-packages\zmq\sugar\socket.py:618, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     611         data = zmq.Frame(
#     612             data,
#     613             track=track,
#     614             copy=copy or None,
#     615             copy_threshold=self.copy_threshold,
#     616         )
#     617     data.group = group
# --> 618 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq\backend\cython\socket.pyx:740, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:787, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:244, in zmq.backend.cython.socket._send_copy()
#
# File D:\Anaconda\envs\tf-gpu\lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
plt.savefig('graficas.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 acc = history.history['accuracy']
#       2 val_acc = history.history['val_accuracy']
#       4 loss = history.history['loss']
#
# NameError: name 'history' is not defined

# %%
model.save("test11_transformer.h5")
